# %%
# !ls dataset/val/0 | xargs -I {} mv dataset/val/0/{} dataset/train/0/
# !ls dataset/val/1 | xargs -I {} mv dataset/val/1/{} dataset/train/1/

# %%
# !ls dataset/train/0 | xargs -I {} cp dataset/train/0/{} dataset/all
# !ls dataset/train/1 | xargs -I {} cp dataset/train/1/{} dataset/all
# !ls dataset/test/0 | xargs -I {} cp dataset/test/0/{} dataset/test
# !ls dataset/test/1 | xargs -I {} cp dataset/test/1/{} dataset/test

# %%
# !rsync --checksum --files-from=<(ls augmented/train/0) augmented/train/0/ final_dataset/train/0/
# !rsync --checksum --files-from=<(ls dataset/test/0) dataset/test/0 dataset/test/
# !rsync --checksum --files-from=<(ls dataset/test/1) dataset/test/1 dataset/test/

# %% [markdown]
# # Preprocessing Functions

# %%
import cv2
from torchvision.transforms import v2
from PIL import Image
import os
import numpy as np

def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

def crop_image_from_gray(img, tol=20):
    if img.ndim == 2:
        mask = img > tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    elif img.ndim == 3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        mask = gray_img > tol        
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0):
            return img
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
            img = np.stack([img1,img2,img3], axis=-1)
        return img


def circle_crop_v2(img):
    img = crop_image_from_gray(img)

    height, width, depth = img.shape
    largest_side = np.max((height, width))
    img = cv2.resize(img, (largest_side, largest_side))

    height, width, depth = img.shape

    x = int(width / 2)
    y = int(height / 2)
    r = np.amin((x, y))

    circle_img = np.zeros((height, width), np.uint8)
    cv2.circle(circle_img, (x, y), int(r), 1, thickness=-1)
    img = cv2.bitwise_and(img, img, mask=circle_img)
    img = crop_image_from_gray(img)

    return img


def load_ben_color(img, IMG_SIZE=512, sigmaX=7):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = circle_crop_v2(img)
    img = cv2.resize(img,(IMG_SIZE, IMG_SIZE))
    img = cv2.addWeighted (img, 4, cv2.GaussianBlur(img ,(0,0), sigmaX) ,-4 ,128)
        
    return img


# Define CLAHE transformation
def apply_clahe(img):
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    img = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    
    return img

# Function to apply augmentation and save the augmented image
def augment_and_save(input_path, output_path, level, replicate, test=False):
    # Define your augmentation transformations
    if test == True:
        transform = v2.Compose([
            v2.RandomHorizontalFlip(),
            v2.RandomVerticalFlip(),
            v2.RandomRotation(90)
        ])
    else:
        if level == 0:
            transform = v2.Compose([
                v2.RandomHorizontalFlip(),
                v2.RandomVerticalFlip(),
                v2.RandomRotation(90)
            ])
        else:
            transform = v2.Compose([
                v2.RandomHorizontalFlip(),
                v2.RandomVerticalFlip(),
                v2.RandomRotation(90),
                v2.RandomPerspective()
            ])
    
    # Set the path to save the augmented image
    # Create a subfolder inside output_path based on the level
    level_folder = os.path.join(output_path, f"{level}")
    os.makedirs(level_folder, exist_ok=True)

    augmented_image_filename = f"{replicate}_{os.path.basename(input_path)}"
    augmented_image_path = os.path.join(level_folder, augmented_image_filename)

    # Check if the augmented image already exists, and skip if it does
    if os.path.exists(augmented_image_path):
        print(f"Skipping existing file: {augmented_image_path}")
        return

    # Load the image as PIL Image
    image = Image.open(input_path)

    # Convert PIL Image to NumPy array
    image_np = np.array(image)

    # Apply the transformations
    image_np = load_ben_color(image_np)
    image_np = apply_clahe(image_np)

    # Convert NumPy array to PIL Image
    image_pil = Image.fromarray(image_np)
    augmented_image = transform(image_pil)

    # Save the augmented image to the subfolder
    augmented_image.save(augmented_image_path)

# %% [markdown]
# # Preprocessing Training Images

# %%
import os
import pandas as pd

# Read the CSV file
csv_path = 'dataset/train.csv'
df = pd.read_csv(csv_path)

# Set the path to the folder containing your images
image_folder_path = 'dataset/train'

# Set the path to the output folder for augmented images
output_folder_path = 'augmented2/train'
os.makedirs(output_folder_path, exist_ok=True)

print("Processing images...")

# Iterate through the CSV file and apply augmentation
n = 0
for index, row in df.iterrows():
    image_name, level = row['image'], row['level']
    image_path = os.path.join(image_folder_path, f"{image_name}.jpeg")  # Adjust the extension based on your image format

    if level == 0:
        augment_and_save(image_path, output_folder_path, level, replicate=1)
    elif level == 1:
        for i in range(5):
            augment_and_save(image_path, output_folder_path, level, replicate=i)
    elif level == 2:
        for i in range(2):
            augment_and_save(image_path, output_folder_path, level, replicate=i)
    elif level == 3:
        for i in range(13):
            augment_and_save(image_path, output_folder_path, level, replicate=i)
    elif level == 4:
        for i in range(16):
            augment_and_save(image_path, output_folder_path, level, replicate=i)
    
    n += 1
    if n % 500 == 0:
        print(f"Processed {n} images.")
print("Processing complete!")
# Out:
# Processing images...
# Skipping existing file: augmented2/train/0/1_10_left.jpeg
# Skipping existing file: augmented2/train/0/1_10_right.jpeg
# Skipping existing file: augmented2/train/0/1_13_left.jpeg
# Skipping existing file: augmented2/train/0/1_13_right.jpeg
# Skipping existing file: augmented2/train/1/0_15_left.jpeg
# Skipping existing file: augmented2/train/1/1_15_left.jpeg
# Skipping existing file: augmented2/train/1/2_15_left.jpeg
# Skipping existing file: augmented2/train/1/3_15_left.jpeg
# Skipping existing file: augmented2/train/1/4_15_left.jpeg
# Skipping existing file: augmented2/train/2/0_15_right.jpeg
# Skipping existing file: augmented2/train/2/1_15_right.jpeg
# Skipping existing file: augmented2/train/4/0_16_left.jpeg
# Skipping existing file: augmented2/train/4/1_16_left.jpeg
# Skipping existing file: augmented2/train/4/2_16_left.jpeg
# Skipping existing file: augmented2/train/4/3_16_left.jpeg
# Skipping existing file: augmented2/train/4/4_16_left.jpeg
# Skipping existing file: augmented2/train/4/5_16_left.jpeg
# Skipping existing file: augmented2/train/4/6_16_left.jpeg
# Skipping existing file: augmented2/train/4/7_16_left.jpeg
# Skipping existing file: augmented2/train/4/8_16_left.jpeg
# Skipping existing file: augmented2/train/4/9_16_left.jpeg
# Skipping existing file: augmented2/train/4/10_16_left.jpeg
# Skipping existing file: augmented2/train/4/11_16_left.jpeg
# Skipping existing file: augmented2/train/4/12_16_left.jpeg
# Skipping existing file: augmented2/train/4/13_16_left.jpeg
# Skipping existing file: augmented2/train/4/14_16_left.jpeg
# Skipping existing file: augmented2/train/4/15_16_left.jpeg
# Skipping existing file: augmented2/train/4/0_16_right.jpeg
# Skipping existing file: augmented2/train/4/1_16_right.jpeg
# Skipping existing file: augmented2/train/4/2_16_right.jpeg
# Skipping existing file: augmented2/train/4/3_16_right.jpeg
# Skipping existing file: augmented2/train/4/4_16_right.jpeg
# Skipping existing file: augmented2/train/4/5_16_right.jpeg
# Skipping existing file: augmented2/train/4/6_16_right.jpeg
# Skipping existing file: augmented2/train/4/7_16_right.jpeg
# Skipping existing file: augmented2/train/4/8_16_right.jpeg
# Skipping existing file: augmented2/train/4/9_16_right.jpeg
# Skipping existing file: augmented2/train/4/10_16_right.jpeg
# Skipping existing file: augmented2/train/4/11_16_right.jpeg
# Skipping existing file: augmented2/train/4/12_16_right.jpeg
# Skipping existing file: augmented2/train/4/13_16_right.jpeg
# Skipping existing file: augmented2/train/4/14_16_right.jpeg
# Skipping existing file: augmented2/train/4/15_16_right.jpeg
# Skipping existing file: augmented2/train/0/1_17_left.jpeg
# Skipping existing file: augmented2/train/1/0_17_right.jpeg
# Skipping existing file: augmented2/train/1/1_17_right.jpeg
# Skipping existing file: augmented2/train/1/2_17_right.jpeg
# Skipping existing file: augmented2/train/1/3_17_right.jpeg
# Skipping existing file: augmented2/train/1/4_17_right.jpeg
# Skipping existing file: augmented2/train/0/1_19_left.jpeg
# Skipping existing file: augmented2/train/0/1_19_right.jpeg
# Skipping existing file: augmented2/train/0/1_20_left.jpeg
# Skipping existing file: augmented2/train/0/1_20_right.jpeg
# Skipping existing file: augmented2/train/0/1_21_left.jpeg
# Skipping existing file: augmented2/train/0/1_21_right.jpeg
# Skipping existing file: augmented2/train/0/1_22_left.jpeg
# Skipping existing file: augmented2/train/0/1_22_right.jpeg
# Skipping existing file: augmented2/train/0/1_23_left.jpeg
# Skipping existing file: augmented2/train/0/1_23_right.jpeg
# Skipping existing file: augmented2/train/0/1_25_left.jpeg
# Skipping existing file: augmented2/train/0/1_25_right.jpeg
# Skipping existing file: augmented2/train/1/0_30_left.jpeg
# Skipping existing file: augmented2/train/1/1_30_left.jpeg
# Skipping existing file: augmented2/train/1/2_30_left.jpeg
# Skipping existing file: augmented2/train/1/3_30_left.jpeg
# Skipping existing file: augmented2/train/1/4_30_left.jpeg
# Skipping existing file: augmented2/train/2/0_30_right.jpeg
# Skipping existing file: augmented2/train/2/1_30_right.jpeg
# Skipping existing file: augmented2/train/0/1_31_left.jpeg
# Skipping existing file: augmented2/train/0/1_31_right.jpeg
# Skipping existing file: augmented2/train/0/1_33_left.jpeg
# Skipping existing file: augmented2/train/0/1_33_right.jpeg
# Skipping existing file: augmented2/train/1/0_36_left.jpeg
# Skipping existing file: augmented2/train/1/1_36_left.jpeg
# Skipping existing file: augmented2/train/1/2_36_left.jpeg
# Skipping existing file: augmented2/train/1/3_36_left.jpeg
# Skipping existing file: augmented2/train/1/4_36_left.jpeg
# Skipping existing file: augmented2/train/0/1_36_right.jpeg
# Skipping existing file: augmented2/train/2/0_40_left.jpeg
# Skipping existing file: augmented2/train/2/1_40_left.jpeg
# Skipping existing file: augmented2/train/0/1_40_right.jpeg
# Skipping existing file: augmented2/train/0/1_41_left.jpeg
# Skipping existing file: augmented2/train/0/1_41_right.jpeg
# Skipping existing file: augmented2/train/0/1_42_left.jpeg
# Skipping existing file: augmented2/train/0/1_42_right.jpeg
# Skipping existing file: augmented2/train/0/1_46_left.jpeg
# Skipping existing file: augmented2/train/0/1_46_right.jpeg
# Skipping existing file: augmented2/train/0/1_47_left.jpeg
# Skipping existing file: augmented2/train/0/1_47_right.jpeg
# Skipping existing file: augmented2/train/0/1_49_left.jpeg
# Skipping existing file: augmented2/train/0/1_49_right.jpeg
# Skipping existing file: augmented2/train/2/0_51_left.jpeg
# Skipping existing file: augmented2/train/2/1_51_left.jpeg
# Skipping existing file: augmented2/train/0/1_51_right.jpeg
# Skipping existing file: augmented2/train/0/1_52_left.jpeg
# Skipping existing file: augmented2/train/0/1_52_right.jpeg
# Skipping existing file: augmented2/train/2/0_54_left.jpeg
# Skipping existing file: augmented2/train/2/1_54_left.jpeg
# Skipping existing file: augmented2/train/2/0_54_right.jpeg
# Skipping existing file: augmented2/train/2/1_54_right.jpeg
# Skipping existing file: augmented2/train/0/1_56_left.jpeg
# Skipping existing file: augmented2/train/0/1_56_right.jpeg
# Skipping existing file: augmented2/train/0/1_57_left.jpeg
# Skipping existing file: augmented2/train/0/1_57_right.jpeg
# Skipping existing file: augmented2/train/0/1_58_left.jpeg
# Skipping existing file: augmented2/train/0/1_58_right.jpeg
# Skipping existing file: augmented2/train/0/1_59_left.jpeg
# Skipping existing file: augmented2/train/0/1_59_right.jpeg
# Skipping existing file: augmented2/train/0/1_60_left.jpeg
# Skipping existing file: augmented2/train/0/1_60_right.jpeg
# Skipping existing file: augmented2/train/0/1_62_left.jpeg
# Skipping existing file: augmented2/train/0/1_62_right.jpeg
# Skipping existing file: augmented2/train/0/1_64_left.jpeg
# Skipping existing file: augmented2/train/0/1_64_right.jpeg
# Skipping existing file: augmented2/train/0/1_65_left.jpeg
# Skipping existing file: augmented2/train/0/1_65_right.jpeg
# Skipping existing file: augmented2/train/0/1_66_left.jpeg
# Skipping existing file: augmented2/train/0/1_66_right.jpeg
# Skipping existing file: augmented2/train/0/1_67_left.jpeg
# Skipping existing file: augmented2/train/0/1_67_right.jpeg
# Skipping existing file: augmented2/train/0/1_70_left.jpeg
# Skipping existing file: augmented2/train/0/1_70_right.jpeg
# Skipping existing file: augmented2/train/0/1_72_left.jpeg
# Skipping existing file: augmented2/train/0/1_72_right.jpeg
# Skipping existing file: augmented2/train/0/1_73_left.jpeg
# Skipping existing file: augmented2/train/0/1_73_right.jpeg
# Skipping existing file: augmented2/train/0/1_74_left.jpeg
# Skipping existing file: augmented2/train/0/1_74_right.jpeg
# Skipping existing file: augmented2/train/0/1_75_left.jpeg
# Skipping existing file: augmented2/train/0/1_75_right.jpeg
# Skipping existing file: augmented2/train/2/0_78_left.jpeg
# Skipping existing file: augmented2/train/2/1_78_left.jpeg
# Skipping existing file: augmented2/train/2/0_78_right.jpeg
# Skipping existing file: augmented2/train/2/1_78_right.jpeg
# Skipping existing file: augmented2/train/2/0_79_left.jpeg
# Skipping existing file: augmented2/train/2/1_79_left.jpeg
# Skipping existing file: augmented2/train/2/0_79_right.jpeg
# Skipping existing file: augmented2/train/2/1_79_right.jpeg
# Skipping existing file: augmented2/train/0/1_81_left.jpeg
# Skipping existing file: augmented2/train/0/1_81_right.jpeg
# Skipping existing file: augmented2/train/2/0_82_left.jpeg
# Skipping existing file: augmented2/train/2/1_82_left.jpeg
# Skipping existing file: augmented2/train/2/0_82_right.jpeg
# Skipping existing file: augmented2/train/2/1_82_right.jpeg
# Skipping existing file: augmented2/train/0/1_84_left.jpeg
# Skipping existing file: augmented2/train/0/1_84_right.jpeg
# Skipping existing file: augmented2/train/0/1_95_left.jpeg
# Skipping existing file: augmented2/train/0/1_95_right.jpeg
# Skipping existing file: augmented2/train/3/0_99_left.jpeg
# Skipping existing file: augmented2/train/3/1_99_left.jpeg
# Skipping existing file: augmented2/train/3/2_99_left.jpeg
# Skipping existing file: augmented2/train/3/3_99_left.jpeg
# Skipping existing file: augmented2/train/3/4_99_left.jpeg
# Skipping existing file: augmented2/train/3/5_99_left.jpeg
# Skipping existing file: augmented2/train/3/6_99_left.jpeg
# Skipping existing file: augmented2/train/3/7_99_left.jpeg
# Skipping existing file: augmented2/train/3/8_99_left.jpeg
# Skipping existing file: augmented2/train/3/9_99_left.jpeg
# Skipping existing file: augmented2/train/3/10_99_left.jpeg
# Skipping existing file: augmented2/train/3/11_99_left.jpeg
# Skipping existing file: augmented2/train/3/12_99_left.jpeg
# Skipping existing file: augmented2/train/3/0_99_right.jpeg
# Skipping existing file: augmented2/train/3/1_99_right.jpeg
# Skipping existing file: augmented2/train/3/2_99_right.jpeg
# Skipping existing file: augmented2/train/3/3_99_right.jpeg
# Skipping existing file: augmented2/train/3/4_99_right.jpeg
# Skipping existing file: augmented2/train/3/5_99_right.jpeg
# Skipping existing file: augmented2/train/3/6_99_right.jpeg
# Skipping existing file: augmented2/train/3/7_99_right.jpeg
# Skipping existing file: augmented2/train/3/8_99_right.jpeg
# Skipping existing file: augmented2/train/3/9_99_right.jpeg
# Skipping existing file: augmented2/train/3/10_99_right.jpeg
# Skipping existing file: augmented2/train/3/11_99_right.jpeg
# Skipping existing file: augmented2/train/3/12_99_right.jpeg
# Skipping existing file: augmented2/train/0/1_100_left.jpeg
# Skipping existing file: augmented2/train/0/1_100_right.jpeg
# Skipping existing file: augmented2/train/0/1_102_left.jpeg
# Skipping existing file: augmented2/train/0/1_102_right.jpeg
# Skipping existing file: augmented2/train/0/1_104_left.jpeg
# Skipping existing file: augmented2/train/0/1_104_right.jpeg
# Skipping existing file: augmented2/train/0/1_108_left.jpeg
# Skipping existing file: augmented2/train/0/1_108_right.jpeg
# Skipping existing file: augmented2/train/0/1_111_left.jpeg
# Skipping existing file: augmented2/train/0/1_111_right.jpeg
# Skipping existing file: augmented2/train/1/0_114_left.jpeg
# Skipping existing file: augmented2/train/1/1_114_left.jpeg
# Skipping existing file: augmented2/train/1/2_114_left.jpeg
# Skipping existing file: augmented2/train/1/3_114_left.jpeg
# Skipping existing file: augmented2/train/1/4_114_left.jpeg
# Skipping existing file: augmented2/train/1/0_114_right.jpeg
# Skipping existing file: augmented2/train/1/1_114_right.jpeg
# Skipping existing file: augmented2/train/1/2_114_right.jpeg
# Skipping existing file: augmented2/train/1/3_114_right.jpeg
# Skipping existing file: augmented2/train/1/4_114_right.jpeg
# Skipping existing file: augmented2/train/0/1_115_left.jpeg
# Skipping existing file: augmented2/train/0/1_115_right.jpeg
# Skipping existing file: augmented2/train/0/1_117_left.jpeg
# Skipping existing file: augmented2/train/0/1_117_right.jpeg
# Skipping existing file: augmented2/train/0/1_119_left.jpeg
# Skipping existing file: augmented2/train/0/1_119_right.jpeg
# Skipping existing file: augmented2/train/0/1_122_left.jpeg
# Skipping existing file: augmented2/train/0/1_122_right.jpeg
# Skipping existing file: augmented2/train/0/1_125_left.jpeg
# Skipping existing file: augmented2/train/0/1_125_right.jpeg
# Skipping existing file: augmented2/train/2/0_129_left.jpeg
# Skipping existing file: augmented2/train/2/1_129_left.jpeg
# Skipping existing file: augmented2/train/2/0_129_right.jpeg
# Skipping existing file: augmented2/train/2/1_129_right.jpeg
# Skipping existing file: augmented2/train/0/1_140_left.jpeg
# Skipping existing file: augmented2/train/0/1_140_right.jpeg
# Skipping existing file: augmented2/train/0/1_145_left.jpeg
# Skipping existing file: augmented2/train/0/1_145_right.jpeg
# Skipping existing file: augmented2/train/0/1_149_left.jpeg
# Skipping existing file: augmented2/train/0/1_149_right.jpeg
# Skipping existing file: augmented2/train/0/1_155_left.jpeg
# Skipping existing file: augmented2/train/2/0_155_right.jpeg
# Skipping existing file: augmented2/train/2/1_155_right.jpeg
# Skipping existing file: augmented2/train/0/1_156_left.jpeg
# Skipping existing file: augmented2/train/0/1_156_right.jpeg
# Skipping existing file: augmented2/train/0/1_157_left.jpeg
# Skipping existing file: augmented2/train/0/1_157_right.jpeg
# Skipping existing file: augmented2/train/0/1_159_left.jpeg
# Skipping existing file: augmented2/train/0/1_159_right.jpeg
# Skipping existing file: augmented2/train/0/1_161_left.jpeg
# Skipping existing file: augmented2/train/0/1_161_right.jpeg
# Skipping existing file: augmented2/train/0/1_162_left.jpeg
# Skipping existing file: augmented2/train/0/1_162_right.jpeg
# Skipping existing file: augmented2/train/3/0_163_left.jpeg
# Skipping existing file: augmented2/train/3/1_163_left.jpeg
# Skipping existing file: augmented2/train/3/2_163_left.jpeg
# Skipping existing file: augmented2/train/3/3_163_left.jpeg
# Skipping existing file: augmented2/train/3/4_163_left.jpeg
# Skipping existing file: augmented2/train/3/5_163_left.jpeg
# Skipping existing file: augmented2/train/3/6_163_left.jpeg
# Skipping existing file: augmented2/train/3/7_163_left.jpeg
# Skipping existing file: augmented2/train/3/8_163_left.jpeg
# Skipping existing file: augmented2/train/3/9_163_left.jpeg
# Skipping existing file: augmented2/train/3/10_163_left.jpeg
# Skipping existing file: augmented2/train/3/11_163_left.jpeg
# Skipping existing file: augmented2/train/3/12_163_left.jpeg
# Skipping existing file: augmented2/train/3/0_163_right.jpeg
# Skipping existing file: augmented2/train/3/1_163_right.jpeg
# Skipping existing file: augmented2/train/3/2_163_right.jpeg
# Skipping existing file: augmented2/train/3/3_163_right.jpeg
# Skipping existing file: augmented2/train/3/4_163_right.jpeg
# Skipping existing file: augmented2/train/3/5_163_right.jpeg
# Skipping existing file: augmented2/train/3/6_163_right.jpeg
# Skipping existing file: augmented2/train/3/7_163_right.jpeg
# Skipping existing file: augmented2/train/3/8_163_right.jpeg
# Skipping existing file: augmented2/train/3/9_163_right.jpeg
# Skipping existing file: augmented2/train/3/10_163_right.jpeg
# Skipping existing file: augmented2/train/3/11_163_right.jpeg
# Skipping existing file: augmented2/train/3/12_163_right.jpeg
# Skipping existing file: augmented2/train/0/1_164_left.jpeg
# Skipping existing file: augmented2/train/0/1_164_right.jpeg
# Skipping existing file: augmented2/train/0/1_167_left.jpeg
# Skipping existing file: augmented2/train/0/1_167_right.jpeg
# Skipping existing file: augmented2/train/0/1_169_left.jpeg
# Skipping existing file: augmented2/train/0/1_169_right.jpeg
# Skipping existing file: augmented2/train/0/1_170_left.jpeg
# Skipping existing file: augmented2/train/0/1_170_right.jpeg
# Skipping existing file: augmented2/train/2/0_172_left.jpeg
# Skipping existing file: augmented2/train/2/1_172_left.jpeg
# Skipping existing file: augmented2/train/2/0_172_right.jpeg
# Skipping existing file: augmented2/train/2/1_172_right.jpeg
# Skipping existing file: augmented2/train/0/1_174_left.jpeg
# Skipping existing file: augmented2/train/0/1_174_right.jpeg
# Skipping existing file: augmented2/train/0/1_177_left.jpeg
# Skipping existing file: augmented2/train/0/1_177_right.jpeg
# Skipping existing file: augmented2/train/1/0_178_left.jpeg
# Skipping existing file: augmented2/train/1/1_178_left.jpeg
# Skipping existing file: augmented2/train/1/2_178_left.jpeg
# Skipping existing file: augmented2/train/1/3_178_left.jpeg
# Skipping existing file: augmented2/train/1/4_178_left.jpeg
# Skipping existing file: augmented2/train/1/0_178_right.jpeg
# Skipping existing file: augmented2/train/1/1_178_right.jpeg
# Skipping existing file: augmented2/train/1/2_178_right.jpeg
# Skipping existing file: augmented2/train/1/3_178_right.jpeg
# Skipping existing file: augmented2/train/1/4_178_right.jpeg
# Skipping existing file: augmented2/train/0/1_179_left.jpeg
# Skipping existing file: augmented2/train/0/1_179_right.jpeg
# Skipping existing file: augmented2/train/2/0_184_left.jpeg
# Skipping existing file: augmented2/train/2/1_184_left.jpeg
# Skipping existing file: augmented2/train/2/0_184_right.jpeg
# Skipping existing file: augmented2/train/2/1_184_right.jpeg
# Skipping existing file: augmented2/train/0/1_186_left.jpeg
# Skipping existing file: augmented2/train/0/1_186_right.jpeg
# Skipping existing file: augmented2/train/0/1_190_left.jpeg
# Skipping existing file: augmented2/train/0/1_190_right.jpeg
# Skipping existing file: augmented2/train/2/0_192_left.jpeg
# Skipping existing file: augmented2/train/2/1_192_left.jpeg
# Skipping existing file: augmented2/train/2/0_192_right.jpeg
# Skipping existing file: augmented2/train/2/1_192_right.jpeg
# Skipping existing file: augmented2/train/0/1_194_left.jpeg
# Skipping existing file: augmented2/train/0/1_194_right.jpeg
# Skipping existing file: augmented2/train/2/0_195_left.jpeg
# Skipping existing file: augmented2/train/2/1_195_left.jpeg
# Skipping existing file: augmented2/train/2/0_195_right.jpeg
# Skipping existing file: augmented2/train/2/1_195_right.jpeg
# Skipping existing file: augmented2/train/0/1_197_left.jpeg
# Skipping existing file: augmented2/train/0/1_197_right.jpeg
# Skipping existing file: augmented2/train/0/1_199_left.jpeg
# Skipping existing file: augmented2/train/0/1_199_right.jpeg
# Skipping existing file: augmented2/train/0/1_203_left.jpeg
# Skipping existing file: augmented2/train/0/1_203_right.jpeg
# Skipping existing file: augmented2/train/0/1_204_left.jpeg
# Skipping existing file: augmented2/train/1/0_204_right.jpeg
# Skipping existing file: augmented2/train/1/1_204_right.jpeg
# Skipping existing file: augmented2/train/1/2_204_right.jpeg
# Skipping existing file: augmented2/train/1/3_204_right.jpeg
# Skipping existing file: augmented2/train/1/4_204_right.jpeg
# Skipping existing file: augmented2/train/0/1_208_left.jpeg
# Skipping existing file: augmented2/train/0/1_208_right.jpeg
# Skipping existing file: augmented2/train/0/1_210_left.jpeg
# Skipping existing file: augmented2/train/0/1_210_right.jpeg
# Skipping existing file: augmented2/train/0/1_211_left.jpeg
# Skipping existing file: augmented2/train/0/1_211_right.jpeg
# Skipping existing file: augmented2/train/1/0_214_left.jpeg
# Skipping existing file: augmented2/train/1/1_214_left.jpeg
# Skipping existing file: augmented2/train/1/2_214_left.jpeg
# Skipping existing file: augmented2/train/1/3_214_left.jpeg
# Skipping existing file: augmented2/train/1/4_214_left.jpeg
# Skipping existing file: augmented2/train/0/1_214_right.jpeg
# Skipping existing file: augmented2/train/0/1_216_left.jpeg
# Skipping existing file: augmented2/train/0/1_216_right.jpeg
# Skipping existing file: augmented2/train/4/0_217_left.jpeg
# Skipping existing file: augmented2/train/4/1_217_left.jpeg
# Skipping existing file: augmented2/train/4/2_217_left.jpeg
# Skipping existing file: augmented2/train/4/3_217_left.jpeg
# Skipping existing file: augmented2/train/4/4_217_left.jpeg
# Skipping existing file: augmented2/train/4/5_217_left.jpeg
# Skipping existing file: augmented2/train/4/6_217_left.jpeg
# Skipping existing file: augmented2/train/4/7_217_left.jpeg
# Skipping existing file: augmented2/train/4/8_217_left.jpeg
# Skipping existing file: augmented2/train/4/9_217_left.jpeg
# Skipping existing file: augmented2/train/4/10_217_left.jpeg
# Skipping existing file: augmented2/train/4/11_217_left.jpeg
# Skipping existing file: augmented2/train/4/12_217_left.jpeg
# Skipping existing file: augmented2/train/4/13_217_left.jpeg
# Skipping existing file: augmented2/train/4/14_217_left.jpeg
# Skipping existing file: augmented2/train/4/15_217_left.jpeg
# Skipping existing file: augmented2/train/4/0_217_right.jpeg
# Skipping existing file: augmented2/train/4/1_217_right.jpeg
# Skipping existing file: augmented2/train/4/2_217_right.jpeg
# Skipping existing file: augmented2/train/4/3_217_right.jpeg
# Skipping existing file: augmented2/train/4/4_217_right.jpeg
# Skipping existing file: augmented2/train/4/5_217_right.jpeg
# Skipping existing file: augmented2/train/4/6_217_right.jpeg
# Skipping existing file: augmented2/train/4/7_217_right.jpeg
# Skipping existing file: augmented2/train/4/8_217_right.jpeg
# Skipping existing file: augmented2/train/4/9_217_right.jpeg
# Skipping existing file: augmented2/train/4/10_217_right.jpeg
# Skipping existing file: augmented2/train/4/11_217_right.jpeg
# Skipping existing file: augmented2/train/4/12_217_right.jpeg
# Skipping existing file: augmented2/train/4/13_217_right.jpeg
# Skipping existing file: augmented2/train/4/14_217_right.jpeg
# Skipping existing file: augmented2/train/4/15_217_right.jpeg
# Skipping existing file: augmented2/train/0/1_218_left.jpeg
# Skipping existing file: augmented2/train/0/1_218_right.jpeg
# Skipping existing file: augmented2/train/2/0_219_left.jpeg
# Skipping existing file: augmented2/train/2/1_219_left.jpeg
# Skipping existing file: augmented2/train/0/1_219_right.jpeg
# Skipping existing file: augmented2/train/0/1_222_left.jpeg
# Skipping existing file: augmented2/train/0/1_222_right.jpeg
# Skipping existing file: augmented2/train/0/1_224_left.jpeg
# Skipping existing file: augmented2/train/0/1_224_right.jpeg
# Skipping existing file: augmented2/train/0/1_225_left.jpeg
# Skipping existing file: augmented2/train/0/1_225_right.jpeg
# Skipping existing file: augmented2/train/1/0_227_left.jpeg
# Skipping existing file: augmented2/train/1/1_227_left.jpeg
# Skipping existing file: augmented2/train/1/2_227_left.jpeg
# Skipping existing file: augmented2/train/1/3_227_left.jpeg
# Skipping existing file: augmented2/train/1/4_227_left.jpeg
# Skipping existing file: augmented2/train/0/1_227_right.jpeg
# Skipping existing file: augmented2/train/0/1_229_left.jpeg
# Skipping existing file: augmented2/train/2/0_229_right.jpeg
# Skipping existing file: augmented2/train/2/1_229_right.jpeg
# Skipping existing file: augmented2/train/1/0_231_left.jpeg
# Skipping existing file: augmented2/train/1/1_231_left.jpeg
# Skipping existing file: augmented2/train/1/2_231_left.jpeg
# Skipping existing file: augmented2/train/1/3_231_left.jpeg
# Skipping existing file: augmented2/train/1/4_231_left.jpeg
# Skipping existing file: augmented2/train/0/1_231_right.jpeg
# Skipping existing file: augmented2/train/0/1_232_left.jpeg
# Skipping existing file: augmented2/train/0/1_232_right.jpeg
# Skipping existing file: augmented2/train/0/1_234_left.jpeg
# Skipping existing file: augmented2/train/0/1_234_right.jpeg
# Skipping existing file: augmented2/train/0/1_236_left.jpeg
# Skipping existing file: augmented2/train/0/1_236_right.jpeg
# Skipping existing file: augmented2/train/2/0_239_left.jpeg
# Skipping existing file: augmented2/train/2/1_239_left.jpeg
# Skipping existing file: augmented2/train/2/0_239_right.jpeg
# Skipping existing file: augmented2/train/2/1_239_right.jpeg
# Skipping existing file: augmented2/train/0/1_240_left.jpeg
# Skipping existing file: augmented2/train/1/0_240_right.jpeg
# Skipping existing file: augmented2/train/1/1_240_right.jpeg
# Skipping existing file: augmented2/train/1/2_240_right.jpeg
# Skipping existing file: augmented2/train/1/3_240_right.jpeg
# Skipping existing file: augmented2/train/1/4_240_right.jpeg
# Skipping existing file: augmented2/train/0/1_241_left.jpeg
# Skipping existing file: augmented2/train/0/1_241_right.jpeg
# Skipping existing file: augmented2/train/0/1_242_left.jpeg
# Skipping existing file: augmented2/train/0/1_242_right.jpeg
# Skipping existing file: augmented2/train/0/1_244_left.jpeg
# Skipping existing file: augmented2/train/0/1_244_right.jpeg
# Skipping existing file: augmented2/train/0/1_249_left.jpeg
# Skipping existing file: augmented2/train/0/1_249_right.jpeg
# Skipping existing file: augmented2/train/0/1_252_left.jpeg
# Skipping existing file: augmented2/train/0/1_252_right.jpeg
# Skipping existing file: augmented2/train/0/1_256_left.jpeg
# Skipping existing file: augmented2/train/0/1_256_right.jpeg
# Skipping existing file: augmented2/train/2/0_257_left.jpeg
# Skipping existing file: augmented2/train/2/1_257_left.jpeg
# Skipping existing file: augmented2/train/2/0_257_right.jpeg
# Skipping existing file: augmented2/train/2/1_257_right.jpeg
# Skipping existing file: augmented2/train/0/1_258_left.jpeg
# Skipping existing file: augmented2/train/0/1_258_right.jpeg
# Skipping existing file: augmented2/train/0/1_259_left.jpeg
# Skipping existing file: augmented2/train/0/1_259_right.jpeg
# Skipping existing file: augmented2/train/0/1_260_left.jpeg
# Skipping existing file: augmented2/train/0/1_260_right.jpeg
# Skipping existing file: augmented2/train/0/1_263_left.jpeg
# Skipping existing file: augmented2/train/0/1_263_right.jpeg
# Skipping existing file: augmented2/train/2/0_264_left.jpeg
# Skipping existing file: augmented2/train/2/1_264_left.jpeg
# Skipping existing file: augmented2/train/2/0_264_right.jpeg
# Skipping existing file: augmented2/train/2/1_264_right.jpeg
# Skipping existing file: augmented2/train/0/1_274_left.jpeg
# Skipping existing file: augmented2/train/0/1_274_right.jpeg
# Skipping existing file: augmented2/train/0/1_277_left.jpeg
# Skipping existing file: augmented2/train/0/1_277_right.jpeg
# Skipping existing file: augmented2/train/0/1_279_left.jpeg
# Skipping existing file: augmented2/train/0/1_279_right.jpeg
# Skipping existing file: augmented2/train/0/1_280_left.jpeg
# Skipping existing file: augmented2/train/0/1_280_right.jpeg
# Skipping existing file: augmented2/train/2/0_283_left.jpeg
# Skipping existing file: augmented2/train/2/1_283_left.jpeg
# Skipping existing file: augmented2/train/2/0_283_right.jpeg
# Skipping existing file: augmented2/train/2/1_283_right.jpeg
# Skipping existing file: augmented2/train/2/0_286_left.jpeg
# Skipping existing file: augmented2/train/2/1_286_left.jpeg
# Skipping existing file: augmented2/train/2/0_286_right.jpeg
# Skipping existing file: augmented2/train/2/1_286_right.jpeg
# Skipping existing file: augmented2/train/0/1_288_left.jpeg
# Skipping existing file: augmented2/train/0/1_288_right.jpeg
# Skipping existing file: augmented2/train/0/1_289_left.jpeg
# Skipping existing file: augmented2/train/0/1_289_right.jpeg
# Skipping existing file: augmented2/train/4/0_294_left.jpeg
# Skipping existing file: augmented2/train/4/1_294_left.jpeg
# Skipping existing file: augmented2/train/4/2_294_left.jpeg
# Skipping existing file: augmented2/train/4/3_294_left.jpeg
# Skipping existing file: augmented2/train/4/4_294_left.jpeg
# Skipping existing file: augmented2/train/4/5_294_left.jpeg
# Skipping existing file: augmented2/train/4/6_294_left.jpeg
# Skipping existing file: augmented2/train/4/7_294_left.jpeg
# Skipping existing file: augmented2/train/4/8_294_left.jpeg
# Skipping existing file: augmented2/train/4/9_294_left.jpeg
# Skipping existing file: augmented2/train/4/10_294_left.jpeg
# Skipping existing file: augmented2/train/4/11_294_left.jpeg
# Skipping existing file: augmented2/train/4/12_294_left.jpeg
# Skipping existing file: augmented2/train/4/13_294_left.jpeg
# Skipping existing file: augmented2/train/4/14_294_left.jpeg
# Skipping existing file: augmented2/train/4/15_294_left.jpeg
# Skipping existing file: augmented2/train/4/0_294_right.jpeg
# Skipping existing file: augmented2/train/4/1_294_right.jpeg
# Skipping existing file: augmented2/train/4/2_294_right.jpeg
# Skipping existing file: augmented2/train/4/3_294_right.jpeg
# Skipping existing file: augmented2/train/4/4_294_right.jpeg
# Skipping existing file: augmented2/train/4/5_294_right.jpeg
# Skipping existing file: augmented2/train/4/6_294_right.jpeg
# Skipping existing file: augmented2/train/4/7_294_right.jpeg
# Skipping existing file: augmented2/train/4/8_294_right.jpeg
# Skipping existing file: augmented2/train/4/9_294_right.jpeg
# Skipping existing file: augmented2/train/4/10_294_right.jpeg
# Skipping existing file: augmented2/train/4/11_294_right.jpeg
# Skipping existing file: augmented2/train/4/12_294_right.jpeg
# Skipping existing file: augmented2/train/4/13_294_right.jpeg
# Skipping existing file: augmented2/train/4/14_294_right.jpeg
# Skipping existing file: augmented2/train/4/15_294_right.jpeg
# Skipping existing file: augmented2/train/0/1_299_left.jpeg
# Skipping existing file: augmented2/train/0/1_299_right.jpeg
# Skipping existing file: augmented2/train/0/1_301_left.jpeg
# Skipping existing file: augmented2/train/1/0_301_right.jpeg
# Skipping existing file: augmented2/train/1/1_301_right.jpeg
# Skipping existing file: augmented2/train/1/2_301_right.jpeg
# Skipping existing file: augmented2/train/1/3_301_right.jpeg
# Skipping existing file: augmented2/train/1/4_301_right.jpeg
# Skipping existing file: augmented2/train/0/1_307_left.jpeg
# Skipping existing file: augmented2/train/0/1_307_right.jpeg
# Skipping existing file: augmented2/train/0/1_310_left.jpeg
# Skipping existing file: augmented2/train/0/1_310_right.jpeg
# Skipping existing file: augmented2/train/0/1_311_left.jpeg
# Skipping existing file: augmented2/train/0/1_311_right.jpeg
# Skipping existing file: augmented2/train/0/1_314_left.jpeg
# Skipping existing file: augmented2/train/0/1_314_right.jpeg
# Skipping existing file: augmented2/train/0/1_316_left.jpeg
# Skipping existing file: augmented2/train/0/1_316_right.jpeg
# Skipping existing file: augmented2/train/2/0_317_left.jpeg
# Skipping existing file: augmented2/train/2/1_317_left.jpeg
# Skipping existing file: augmented2/train/2/0_317_right.jpeg
# Skipping existing file: augmented2/train/2/1_317_right.jpeg
# Skipping existing file: augmented2/train/0/1_318_left.jpeg
# Skipping existing file: augmented2/train/0/1_318_right.jpeg
# Skipping existing file: augmented2/train/1/0_320_left.jpeg
# Skipping existing file: augmented2/train/1/1_320_left.jpeg
# Skipping existing file: augmented2/train/1/2_320_left.jpeg
# Skipping existing file: augmented2/train/1/3_320_left.jpeg
# Skipping existing file: augmented2/train/1/4_320_left.jpeg
# Skipping existing file: augmented2/train/2/0_320_right.jpeg
# Skipping existing file: augmented2/train/2/1_320_right.jpeg
# Skipping existing file: augmented2/train/0/1_322_left.jpeg
# Skipping existing file: augmented2/train/0/1_322_right.jpeg
# Skipping existing file: augmented2/train/0/1_323_left.jpeg
# Skipping existing file: augmented2/train/0/1_323_right.jpeg
# Skipping existing file: augmented2/train/2/0_325_left.jpeg
# Skipping existing file: augmented2/train/2/1_325_left.jpeg
# Skipping existing file: augmented2/train/2/0_325_right.jpeg
# Skipping existing file: augmented2/train/2/1_325_right.jpeg
# Skipping existing file: augmented2/train/4/0_326_left.jpeg
# Skipping existing file: augmented2/train/4/1_326_left.jpeg
# Skipping existing file: augmented2/train/4/2_326_left.jpeg
# Skipping existing file: augmented2/train/4/3_326_left.jpeg
# Skipping existing file: augmented2/train/4/4_326_left.jpeg
# Skipping existing file: augmented2/train/4/5_326_left.jpeg
# Skipping existing file: augmented2/train/4/6_326_left.jpeg
# Skipping existing file: augmented2/train/4/7_326_left.jpeg
# Skipping existing file: augmented2/train/4/8_326_left.jpeg
# Skipping existing file: augmented2/train/4/9_326_left.jpeg
# Skipping existing file: augmented2/train/4/10_326_left.jpeg
# Skipping existing file: augmented2/train/4/11_326_left.jpeg
# Skipping existing file: augmented2/train/4/12_326_left.jpeg
# Skipping existing file: augmented2/train/4/13_326_left.jpeg
# Skipping existing file: augmented2/train/4/14_326_left.jpeg
# Skipping existing file: augmented2/train/4/15_326_left.jpeg
# Skipping existing file: augmented2/train/4/0_326_right.jpeg
# Skipping existing file: augmented2/train/4/1_326_right.jpeg
# Skipping existing file: augmented2/train/4/2_326_right.jpeg
# Skipping existing file: augmented2/train/4/3_326_right.jpeg
# Skipping existing file: augmented2/train/4/4_326_right.jpeg
# Skipping existing file: augmented2/train/4/5_326_right.jpeg
# Skipping existing file: augmented2/train/4/6_326_right.jpeg
# Skipping existing file: augmented2/train/4/7_326_right.jpeg
# Skipping existing file: augmented2/train/4/8_326_right.jpeg
# Skipping existing file: augmented2/train/4/9_326_right.jpeg
# Skipping existing file: augmented2/train/4/10_326_right.jpeg
# Skipping existing file: augmented2/train/4/11_326_right.jpeg
# Skipping existing file: augmented2/train/4/12_326_right.jpeg
# Skipping existing file: augmented2/train/4/13_326_right.jpeg
# Skipping existing file: augmented2/train/4/14_326_right.jpeg
# Skipping existing file: augmented2/train/4/15_326_right.jpeg
# Skipping existing file: augmented2/train/2/0_328_left.jpeg
# Skipping existing file: augmented2/train/2/1_328_left.jpeg
# Skipping existing file: augmented2/train/3/0_328_right.jpeg
# Skipping existing file: augmented2/train/3/1_328_right.jpeg
# Skipping existing file: augmented2/train/3/2_328_right.jpeg
# Skipping existing file: augmented2/train/3/3_328_right.jpeg
# Skipping existing file: augmented2/train/3/4_328_right.jpeg
# Skipping existing file: augmented2/train/3/5_328_right.jpeg
# Skipping existing file: augmented2/train/3/6_328_right.jpeg
# Skipping existing file: augmented2/train/3/7_328_right.jpeg
# Skipping existing file: augmented2/train/3/8_328_right.jpeg
# Skipping existing file: augmented2/train/3/9_328_right.jpeg
# Skipping existing file: augmented2/train/3/10_328_right.jpeg
# Skipping existing file: augmented2/train/3/11_328_right.jpeg
# Skipping existing file: augmented2/train/3/12_328_right.jpeg
# Skipping existing file: augmented2/train/0/1_329_left.jpeg
# Skipping existing file: augmented2/train/0/1_329_right.jpeg
# Skipping existing file: augmented2/train/0/1_330_left.jpeg
# Skipping existing file: augmented2/train/0/1_330_right.jpeg
# Skipping existing file: augmented2/train/0/1_333_left.jpeg
# Skipping existing file: augmented2/train/0/1_333_right.jpeg
# Skipping existing file: augmented2/train/0/1_337_left.jpeg
# Skipping existing file: augmented2/train/2/0_337_right.jpeg
# Skipping existing file: augmented2/train/2/1_337_right.jpeg
# Skipping existing file: augmented2/train/0/1_338_left.jpeg
# Skipping existing file: augmented2/train/0/1_338_right.jpeg
# Skipping existing file: augmented2/train/0/1_343_left.jpeg
# Skipping existing file: augmented2/train/0/1_343_right.jpeg
# Skipping existing file: augmented2/train/1/0_348_left.jpeg
# Skipping existing file: augmented2/train/1/1_348_left.jpeg
# Skipping existing file: augmented2/train/1/2_348_left.jpeg
# Skipping existing file: augmented2/train/1/3_348_left.jpeg
# Skipping existing file: augmented2/train/1/4_348_left.jpeg
# Skipping existing file: augmented2/train/1/0_348_right.jpeg
# Skipping existing file: augmented2/train/1/1_348_right.jpeg
# Skipping existing file: augmented2/train/1/2_348_right.jpeg
# Skipping existing file: augmented2/train/1/3_348_right.jpeg
# Skipping existing file: augmented2/train/1/4_348_right.jpeg
# Skipping existing file: augmented2/train/0/1_349_left.jpeg
# Skipping existing file: augmented2/train/0/1_349_right.jpeg
# Skipping existing file: augmented2/train/3/0_352_left.jpeg
# Skipping existing file: augmented2/train/3/1_352_left.jpeg
# Skipping existing file: augmented2/train/3/2_352_left.jpeg
# Skipping existing file: augmented2/train/3/3_352_left.jpeg
# Skipping existing file: augmented2/train/3/4_352_left.jpeg
# Skipping existing file: augmented2/train/3/5_352_left.jpeg
# Skipping existing file: augmented2/train/3/6_352_left.jpeg
# Skipping existing file: augmented2/train/3/7_352_left.jpeg
# Skipping existing file: augmented2/train/3/8_352_left.jpeg
# Skipping existing file: augmented2/train/3/9_352_left.jpeg
# Skipping existing file: augmented2/train/3/10_352_left.jpeg
# Skipping existing file: augmented2/train/3/11_352_left.jpeg
# Skipping existing file: augmented2/train/3/12_352_left.jpeg
# Skipping existing file: augmented2/train/3/0_352_right.jpeg
# Skipping existing file: augmented2/train/3/1_352_right.jpeg
# Skipping existing file: augmented2/train/3/2_352_right.jpeg
# Skipping existing file: augmented2/train/3/3_352_right.jpeg
# Skipping existing file: augmented2/train/3/4_352_right.jpeg
# Skipping existing file: augmented2/train/3/5_352_right.jpeg
# Skipping existing file: augmented2/train/3/6_352_right.jpeg
# Skipping existing file: augmented2/train/3/7_352_right.jpeg
# Skipping existing file: augmented2/train/3/8_352_right.jpeg
# Skipping existing file: augmented2/train/3/9_352_right.jpeg
# Skipping existing file: augmented2/train/3/10_352_right.jpeg
# Skipping existing file: augmented2/train/3/11_352_right.jpeg
# Skipping existing file: augmented2/train/3/12_352_right.jpeg
# Skipping existing file: augmented2/train/0/1_355_left.jpeg
# Skipping existing file: augmented2/train/0/1_355_right.jpeg
# Skipping existing file: augmented2/train/0/1_356_left.jpeg
# Skipping existing file: augmented2/train/0/1_356_right.jpeg
# Skipping existing file: augmented2/train/0/1_358_left.jpeg
# Skipping existing file: augmented2/train/0/1_358_right.jpeg
# Skipping existing file: augmented2/train/2/0_360_left.jpeg
# Skipping existing file: augmented2/train/2/1_360_left.jpeg
# Skipping existing file: augmented2/train/2/0_360_right.jpeg
# Skipping existing file: augmented2/train/2/1_360_right.jpeg
# Skipping existing file: augmented2/train/0/1_363_left.jpeg
# Skipping existing file: augmented2/train/0/1_363_right.jpeg
# Skipping existing file: augmented2/train/0/1_364_left.jpeg
# Skipping existing file: augmented2/train/0/1_364_right.jpeg
# Skipping existing file: augmented2/train/4/0_367_left.jpeg
# Skipping existing file: augmented2/train/4/1_367_left.jpeg
# Skipping existing file: augmented2/train/4/2_367_left.jpeg
# Skipping existing file: augmented2/train/4/3_367_left.jpeg
# Skipping existing file: augmented2/train/4/4_367_left.jpeg
# Skipping existing file: augmented2/train/4/5_367_left.jpeg
# Skipping existing file: augmented2/train/4/6_367_left.jpeg
# Skipping existing file: augmented2/train/4/7_367_left.jpeg
# Skipping existing file: augmented2/train/4/8_367_left.jpeg
# Skipping existing file: augmented2/train/4/9_367_left.jpeg
# Skipping existing file: augmented2/train/4/10_367_left.jpeg
# Skipping existing file: augmented2/train/4/11_367_left.jpeg
# Skipping existing file: augmented2/train/4/12_367_left.jpeg
# Skipping existing file: augmented2/train/4/13_367_left.jpeg
# Skipping existing file: augmented2/train/4/14_367_left.jpeg
# Skipping existing file: augmented2/train/4/15_367_left.jpeg
# Skipping existing file: augmented2/train/4/0_367_right.jpeg
# Skipping existing file: augmented2/train/4/1_367_right.jpeg
# Skipping existing file: augmented2/train/4/2_367_right.jpeg
# Skipping existing file: augmented2/train/4/3_367_right.jpeg
# Skipping existing file: augmented2/train/4/4_367_right.jpeg
# Skipping existing file: augmented2/train/4/5_367_right.jpeg
# Skipping existing file: augmented2/train/4/6_367_right.jpeg
# Skipping existing file: augmented2/train/4/7_367_right.jpeg
# Skipping existing file: augmented2/train/4/8_367_right.jpeg
# Skipping existing file: augmented2/train/4/9_367_right.jpeg
# Skipping existing file: augmented2/train/4/10_367_right.jpeg
# Skipping existing file: augmented2/train/4/11_367_right.jpeg
# Skipping existing file: augmented2/train/4/12_367_right.jpeg
# Skipping existing file: augmented2/train/4/13_367_right.jpeg
# Skipping existing file: augmented2/train/4/14_367_right.jpeg
# Skipping existing file: augmented2/train/4/15_367_right.jpeg
# Skipping existing file: augmented2/train/0/1_374_left.jpeg
# Skipping existing file: augmented2/train/1/0_374_right.jpeg
# Skipping existing file: augmented2/train/1/1_374_right.jpeg
# Skipping existing file: augmented2/train/1/2_374_right.jpeg
# Skipping existing file: augmented2/train/1/3_374_right.jpeg
# Skipping existing file: augmented2/train/1/4_374_right.jpeg
# Skipping existing file: augmented2/train/2/0_375_left.jpeg
# Skipping existing file: augmented2/train/2/1_375_left.jpeg
# Skipping existing file: augmented2/train/0/1_375_right.jpeg
# Skipping existing file: augmented2/train/0/1_376_left.jpeg
# Skipping existing file: augmented2/train/0/1_376_right.jpeg
# Skipping existing file: augmented2/train/2/0_378_left.jpeg
# Skipping existing file: augmented2/train/2/1_378_left.jpeg
# Skipping existing file: augmented2/train/2/0_378_right.jpeg
# Skipping existing file: augmented2/train/2/1_378_right.jpeg
# Skipping existing file: augmented2/train/0/1_380_left.jpeg
# Skipping existing file: augmented2/train/0/1_380_right.jpeg
# Skipping existing file: augmented2/train/0/1_381_left.jpeg
# Skipping existing file: augmented2/train/0/1_381_right.jpeg
# Skipping existing file: augmented2/train/0/1_384_left.jpeg
# Skipping existing file: augmented2/train/0/1_384_right.jpeg
# Skipping existing file: augmented2/train/0/1_386_left.jpeg
# Skipping existing file: augmented2/train/0/1_386_right.jpeg
# Skipping existing file: augmented2/train/0/1_389_left.jpeg
# Skipping existing file: augmented2/train/0/1_389_right.jpeg
# Skipping existing file: augmented2/train/2/0_391_left.jpeg
# Skipping existing file: augmented2/train/2/1_391_left.jpeg
# Skipping existing file: augmented2/train/3/0_391_right.jpeg
# Skipping existing file: augmented2/train/3/1_391_right.jpeg
# Skipping existing file: augmented2/train/3/2_391_right.jpeg
# Skipping existing file: augmented2/train/3/3_391_right.jpeg
# Skipping existing file: augmented2/train/3/4_391_right.jpeg
# Skipping existing file: augmented2/train/3/5_391_right.jpeg
# Skipping existing file: augmented2/train/3/6_391_right.jpeg
# Skipping existing file: augmented2/train/3/7_391_right.jpeg
# Skipping existing file: augmented2/train/3/8_391_right.jpeg
# Skipping existing file: augmented2/train/3/9_391_right.jpeg
# Skipping existing file: augmented2/train/3/10_391_right.jpeg
# Skipping existing file: augmented2/train/3/11_391_right.jpeg
# Skipping existing file: augmented2/train/3/12_391_right.jpeg
# Skipping existing file: augmented2/train/0/1_393_left.jpeg
# Skipping existing file: augmented2/train/1/0_393_right.jpeg
# Skipping existing file: augmented2/train/1/1_393_right.jpeg
# Skipping existing file: augmented2/train/1/2_393_right.jpeg
# Skipping existing file: augmented2/train/1/3_393_right.jpeg
# Skipping existing file: augmented2/train/1/4_393_right.jpeg
# Skipping existing file: augmented2/train/0/1_395_left.jpeg
# Skipping existing file: augmented2/train/0/1_395_right.jpeg
# Skipping existing file: augmented2/train/2/0_396_left.jpeg
# Skipping existing file: augmented2/train/2/1_396_left.jpeg
# Skipping existing file: augmented2/train/2/0_396_right.jpeg
# Skipping existing file: augmented2/train/2/1_396_right.jpeg
# Skipping existing file: augmented2/train/0/1_398_left.jpeg
# Skipping existing file: augmented2/train/0/1_398_right.jpeg
# Skipping existing file: augmented2/train/0/1_399_left.jpeg
# Skipping existing file: augmented2/train/0/1_399_right.jpeg
# Skipping existing file: augmented2/train/0/1_400_left.jpeg
# Skipping existing file: augmented2/train/0/1_400_right.jpeg
# Skipping existing file: augmented2/train/0/1_404_left.jpeg
# Skipping existing file: augmented2/train/0/1_404_right.jpeg
# Skipping existing file: augmented2/train/4/0_405_left.jpeg
# Skipping existing file: augmented2/train/4/1_405_left.jpeg
# Skipping existing file: augmented2/train/4/2_405_left.jpeg
# Skipping existing file: augmented2/train/4/3_405_left.jpeg
# Skipping existing file: augmented2/train/4/4_405_left.jpeg
# Skipping existing file: augmented2/train/4/5_405_left.jpeg
# Skipping existing file: augmented2/train/4/6_405_left.jpeg
# Skipping existing file: augmented2/train/4/7_405_left.jpeg
# Skipping existing file: augmented2/train/4/8_405_left.jpeg
# Skipping existing file: augmented2/train/4/9_405_left.jpeg
# Skipping existing file: augmented2/train/4/10_405_left.jpeg
# Skipping existing file: augmented2/train/4/11_405_left.jpeg
# Skipping existing file: augmented2/train/4/12_405_left.jpeg
# Skipping existing file: augmented2/train/4/13_405_left.jpeg
# Skipping existing file: augmented2/train/4/14_405_left.jpeg
# Skipping existing file: augmented2/train/4/15_405_left.jpeg
# Skipping existing file: augmented2/train/4/0_405_right.jpeg
# Skipping existing file: augmented2/train/4/1_405_right.jpeg
# Skipping existing file: augmented2/train/4/2_405_right.jpeg
# Skipping existing file: augmented2/train/4/3_405_right.jpeg
# Skipping existing file: augmented2/train/4/4_405_right.jpeg
# Skipping existing file: augmented2/train/4/5_405_right.jpeg
# Skipping existing file: augmented2/train/4/6_405_right.jpeg
# Skipping existing file: augmented2/train/4/7_405_right.jpeg
# Skipping existing file: augmented2/train/4/8_405_right.jpeg
# Skipping existing file: augmented2/train/4/9_405_right.jpeg
# Skipping existing file: augmented2/train/4/10_405_right.jpeg
# Skipping existing file: augmented2/train/4/11_405_right.jpeg
# Skipping existing file: augmented2/train/4/12_405_right.jpeg
# Skipping existing file: augmented2/train/4/13_405_right.jpeg
# Skipping existing file: augmented2/train/4/14_405_right.jpeg
# Skipping existing file: augmented2/train/4/15_405_right.jpeg
# Skipping existing file: augmented2/train/4/0_406_left.jpeg
# Skipping existing file: augmented2/train/4/1_406_left.jpeg
# Skipping existing file: augmented2/train/4/2_406_left.jpeg
# Skipping existing file: augmented2/train/4/3_406_left.jpeg
# Skipping existing file: augmented2/train/4/4_406_left.jpeg
# Skipping existing file: augmented2/train/4/5_406_left.jpeg
# Skipping existing file: augmented2/train/4/6_406_left.jpeg
# Skipping existing file: augmented2/train/4/7_406_left.jpeg
# Skipping existing file: augmented2/train/4/8_406_left.jpeg
# Skipping existing file: augmented2/train/4/9_406_left.jpeg
# Skipping existing file: augmented2/train/4/10_406_left.jpeg
# Skipping existing file: augmented2/train/4/11_406_left.jpeg
# Skipping existing file: augmented2/train/4/12_406_left.jpeg
# Skipping existing file: augmented2/train/4/13_406_left.jpeg
# Skipping existing file: augmented2/train/4/14_406_left.jpeg
# Skipping existing file: augmented2/train/4/15_406_left.jpeg
# Skipping existing file: augmented2/train/4/0_406_right.jpeg
# Skipping existing file: augmented2/train/4/1_406_right.jpeg
# Skipping existing file: augmented2/train/4/2_406_right.jpeg
# Skipping existing file: augmented2/train/4/3_406_right.jpeg
# Skipping existing file: augmented2/train/4/4_406_right.jpeg
# Skipping existing file: augmented2/train/4/5_406_right.jpeg
# Skipping existing file: augmented2/train/4/6_406_right.jpeg
# Skipping existing file: augmented2/train/4/7_406_right.jpeg
# Skipping existing file: augmented2/train/4/8_406_right.jpeg
# Skipping existing file: augmented2/train/4/9_406_right.jpeg
# Skipping existing file: augmented2/train/4/10_406_right.jpeg
# Skipping existing file: augmented2/train/4/11_406_right.jpeg
# Skipping existing file: augmented2/train/4/12_406_right.jpeg
# Skipping existing file: augmented2/train/4/13_406_right.jpeg
# Skipping existing file: augmented2/train/4/14_406_right.jpeg
# Skipping existing file: augmented2/train/4/15_406_right.jpeg
# Skipping existing file: augmented2/train/0/1_408_left.jpeg
# Skipping existing file: augmented2/train/0/1_408_right.jpeg
# Skipping existing file: augmented2/train/0/1_410_left.jpeg
# Skipping existing file: augmented2/train/0/1_410_right.jpeg
# Skipping existing file: augmented2/train/0/1_412_left.jpeg
# Skipping existing file: augmented2/train/0/1_412_right.jpeg
# Skipping existing file: augmented2/train/1/0_417_left.jpeg
# Skipping existing file: augmented2/train/1/1_417_left.jpeg
# Skipping existing file: augmented2/train/1/2_417_left.jpeg
# Skipping existing file: augmented2/train/1/3_417_left.jpeg
# Skipping existing file: augmented2/train/1/4_417_left.jpeg
# Skipping existing file: augmented2/train/1/0_417_right.jpeg
# Skipping existing file: augmented2/train/1/1_417_right.jpeg
# Skipping existing file: augmented2/train/1/2_417_right.jpeg
# Skipping existing file: augmented2/train/1/3_417_right.jpeg
# Skipping existing file: augmented2/train/1/4_417_right.jpeg
# Skipping existing file: augmented2/train/0/1_418_left.jpeg
# Skipping existing file: augmented2/train/0/1_418_right.jpeg
# Skipping existing file: augmented2/train/2/0_419_left.jpeg
# Skipping existing file: augmented2/train/2/1_419_left.jpeg
# Skipping existing file: augmented2/train/2/0_419_right.jpeg
# ...
# Skipping existing file: augmented2/train/0/1_29682_left.jpeg
# Skipping existing file: augmented2/train/0/1_29682_right.jpeg
# Skipping existing file: augmented2/train/2/0_29684_left.jpeg
# Skipping existing file: augmented2/train/2/1_29684_left.jpeg
# Skipping existing file: augmented2/train/1/0_29684_right.jpeg
# Skipping existing file: augmented2/train/1/1_29684_right.jpeg
# Skipping existing file: augmented2/train/1/2_29684_right.jpeg
# Skipping existing file: augmented2/train/1/3_29684_right.jpeg
# Skipping existing file: augmented2/train/1/4_29684_right.jpeg
# Skipping existing file: augmented2/train/0/1_29686_left.jpeg
# Skipping existing file: augmented2/train/0/1_29686_right.jpeg
# Skipping existing file: augmented2/train/0/1_29688_left.jpeg
# Skipping existing file: augmented2/train/0/1_29688_right.jpeg
# Skipping existing file: augmented2/train/0/1_29690_left.jpeg
# Skipping existing file: augmented2/train/0/1_29690_right.jpeg
# Skipping existing file: augmented2/train/0/1_29696_left.jpeg
# Skipping existing file: augmented2/train/0/1_29696_right.jpeg
# Skipping existing file: augmented2/train/0/1_29700_left.jpeg
# Skipping existing file: augmented2/train/0/1_29700_right.jpeg
# Skipping existing file: augmented2/train/0/1_29702_left.jpeg
# Skipping existing file: augmented2/train/0/1_29702_right.jpeg
# Processed 23500 images.
# Skipping existing file: augmented2/train/4/0_29703_left.jpeg
# Skipping existing file: augmented2/train/4/1_29703_left.jpeg
# Skipping existing file: augmented2/train/4/2_29703_left.jpeg
# Skipping existing file: augmented2/train/4/3_29703_left.jpeg
# Skipping existing file: augmented2/train/4/4_29703_left.jpeg
# Skipping existing file: augmented2/train/4/5_29703_left.jpeg
# Skipping existing file: augmented2/train/4/6_29703_left.jpeg
# Skipping existing file: augmented2/train/4/7_29703_left.jpeg
# Skipping existing file: augmented2/train/4/8_29703_left.jpeg
# Skipping existing file: augmented2/train/4/9_29703_left.jpeg
# Skipping existing file: augmented2/train/4/10_29703_left.jpeg
# Skipping existing file: augmented2/train/4/11_29703_left.jpeg
# Skipping existing file: augmented2/train/4/12_29703_left.jpeg
# Skipping existing file: augmented2/train/4/13_29703_left.jpeg
# Skipping existing file: augmented2/train/4/14_29703_left.jpeg
# Skipping existing file: augmented2/train/4/15_29703_left.jpeg
# Skipping existing file: augmented2/train/4/0_29703_right.jpeg
# Skipping existing file: augmented2/train/4/1_29703_right.jpeg
# Skipping existing file: augmented2/train/4/2_29703_right.jpeg
# Skipping existing file: augmented2/train/4/3_29703_right.jpeg
# Skipping existing file: augmented2/train/4/4_29703_right.jpeg
# Skipping existing file: augmented2/train/4/5_29703_right.jpeg
# Skipping existing file: augmented2/train/4/6_29703_right.jpeg
# Skipping existing file: augmented2/train/4/7_29703_right.jpeg
# Skipping existing file: augmented2/train/4/8_29703_right.jpeg
# Skipping existing file: augmented2/train/4/9_29703_right.jpeg
# Skipping existing file: augmented2/train/4/10_29703_right.jpeg
# Skipping existing file: augmented2/train/4/11_29703_right.jpeg
# Skipping existing file: augmented2/train/4/12_29703_right.jpeg
# Skipping existing file: augmented2/train/4/13_29703_right.jpeg
# Skipping existing file: augmented2/train/4/14_29703_right.jpeg
# Skipping existing file: augmented2/train/4/15_29703_right.jpeg
# Skipping existing file: augmented2/train/0/1_29704_left.jpeg
# Skipping existing file: augmented2/train/0/1_29704_right.jpeg
# Skipping existing file: augmented2/train/2/0_29705_left.jpeg
# Skipping existing file: augmented2/train/2/1_29705_left.jpeg
# Skipping existing file: augmented2/train/2/0_29705_right.jpeg
# Skipping existing file: augmented2/train/2/1_29705_right.jpeg
# Skipping existing file: augmented2/train/0/1_29706_left.jpeg
# Skipping existing file: augmented2/train/0/1_29706_right.jpeg
# Skipping existing file: augmented2/train/0/1_29708_left.jpeg
# Skipping existing file: augmented2/train/0/1_29708_right.jpeg
# Skipping existing file: augmented2/train/0/1_29709_left.jpeg
# Skipping existing file: augmented2/train/0/1_29709_right.jpeg
# Skipping existing file: augmented2/train/0/1_29710_left.jpeg
# Skipping existing file: augmented2/train/0/1_29710_right.jpeg
# Skipping existing file: augmented2/train/0/1_29711_left.jpeg
# Skipping existing file: augmented2/train/0/1_29711_right.jpeg
# Skipping existing file: augmented2/train/0/1_29712_left.jpeg
# Skipping existing file: augmented2/train/0/1_29712_right.jpeg
# Skipping existing file: augmented2/train/2/0_29713_left.jpeg
# Skipping existing file: augmented2/train/2/1_29713_left.jpeg
# Skipping existing file: augmented2/train/2/0_29713_right.jpeg
# Skipping existing file: augmented2/train/2/1_29713_right.jpeg
# Skipping existing file: augmented2/train/0/1_29722_left.jpeg
# Skipping existing file: augmented2/train/0/1_29722_right.jpeg
# Skipping existing file: augmented2/train/0/1_29723_left.jpeg
# Skipping existing file: augmented2/train/0/1_29723_right.jpeg
# Skipping existing file: augmented2/train/0/1_29726_left.jpeg
# Skipping existing file: augmented2/train/0/1_29726_right.jpeg
# Skipping existing file: augmented2/train/0/1_29727_left.jpeg
# Skipping existing file: augmented2/train/2/0_29727_right.jpeg
# Skipping existing file: augmented2/train/2/1_29727_right.jpeg
# Skipping existing file: augmented2/train/2/0_29730_left.jpeg
# Skipping existing file: augmented2/train/2/1_29730_left.jpeg
# Skipping existing file: augmented2/train/2/0_29730_right.jpeg
# Skipping existing file: augmented2/train/2/1_29730_right.jpeg
# Skipping existing file: augmented2/train/0/1_29732_left.jpeg
# Skipping existing file: augmented2/train/0/1_29732_right.jpeg
# Skipping existing file: augmented2/train/0/1_29734_left.jpeg
# Skipping existing file: augmented2/train/0/1_29734_right.jpeg
# Skipping existing file: augmented2/train/1/0_29737_left.jpeg
# Skipping existing file: augmented2/train/1/1_29737_left.jpeg
# Skipping existing file: augmented2/train/1/2_29737_left.jpeg
# Skipping existing file: augmented2/train/1/3_29737_left.jpeg
# Skipping existing file: augmented2/train/1/4_29737_left.jpeg
# Skipping existing file: augmented2/train/0/1_29737_right.jpeg
# Skipping existing file: augmented2/train/0/1_29739_left.jpeg
# Skipping existing file: augmented2/train/0/1_29739_right.jpeg
# Skipping existing file: augmented2/train/2/0_29740_left.jpeg
# Skipping existing file: augmented2/train/2/1_29740_left.jpeg
# Skipping existing file: augmented2/train/1/0_29740_right.jpeg
# Skipping existing file: augmented2/train/1/1_29740_right.jpeg
# Skipping existing file: augmented2/train/1/2_29740_right.jpeg
# Skipping existing file: augmented2/train/1/3_29740_right.jpeg
# Skipping existing file: augmented2/train/1/4_29740_right.jpeg
# Skipping existing file: augmented2/train/0/1_29741_left.jpeg
# Skipping existing file: augmented2/train/0/1_29741_right.jpeg
# Skipping existing file: augmented2/train/0/1_29744_left.jpeg
# Skipping existing file: augmented2/train/0/1_29744_right.jpeg
# Skipping existing file: augmented2/train/0/1_29746_left.jpeg
# Skipping existing file: augmented2/train/0/1_29746_right.jpeg
# Skipping existing file: augmented2/train/0/1_29751_left.jpeg
# Skipping existing file: augmented2/train/0/1_29751_right.jpeg
# Skipping existing file: augmented2/train/0/1_29752_left.jpeg
# Skipping existing file: augmented2/train/0/1_29752_right.jpeg
# Skipping existing file: augmented2/train/0/1_29754_left.jpeg
# Skipping existing file: augmented2/train/0/1_29754_right.jpeg
# Skipping existing file: augmented2/train/0/1_29755_left.jpeg
# Skipping existing file: augmented2/train/0/1_29755_right.jpeg
# Skipping existing file: augmented2/train/0/1_29758_left.jpeg
# Skipping existing file: augmented2/train/0/1_29758_right.jpeg
# Skipping existing file: augmented2/train/2/0_29760_left.jpeg
# Skipping existing file: augmented2/train/2/1_29760_left.jpeg
# Skipping existing file: augmented2/train/2/0_29760_right.jpeg
# Skipping existing file: augmented2/train/2/1_29760_right.jpeg
# Skipping existing file: augmented2/train/2/0_29762_left.jpeg
# Skipping existing file: augmented2/train/2/1_29762_left.jpeg
# Skipping existing file: augmented2/train/2/0_29762_right.jpeg
# Skipping existing file: augmented2/train/2/1_29762_right.jpeg
# Skipping existing file: augmented2/train/0/1_29764_left.jpeg
# Skipping existing file: augmented2/train/0/1_29764_right.jpeg
# Skipping existing file: augmented2/train/1/0_29768_left.jpeg
# Skipping existing file: augmented2/train/1/1_29768_left.jpeg
# Skipping existing file: augmented2/train/1/2_29768_left.jpeg
# Skipping existing file: augmented2/train/1/3_29768_left.jpeg
# Skipping existing file: augmented2/train/1/4_29768_left.jpeg
# Skipping existing file: augmented2/train/1/0_29768_right.jpeg
# Skipping existing file: augmented2/train/1/1_29768_right.jpeg
# Skipping existing file: augmented2/train/1/2_29768_right.jpeg
# Skipping existing file: augmented2/train/1/3_29768_right.jpeg
# Skipping existing file: augmented2/train/1/4_29768_right.jpeg
# Skipping existing file: augmented2/train/0/1_29771_left.jpeg
# Skipping existing file: augmented2/train/0/1_29771_right.jpeg
# Skipping existing file: augmented2/train/0/1_29772_left.jpeg
# Skipping existing file: augmented2/train/0/1_29772_right.jpeg
# Skipping existing file: augmented2/train/0/1_29773_left.jpeg
# Skipping existing file: augmented2/train/0/1_29773_right.jpeg
# Skipping existing file: augmented2/train/0/1_29775_left.jpeg
# Skipping existing file: augmented2/train/0/1_29775_right.jpeg
# Skipping existing file: augmented2/train/0/1_29776_left.jpeg
# Skipping existing file: augmented2/train/0/1_29776_right.jpeg
# Skipping existing file: augmented2/train/2/0_29777_left.jpeg
# Skipping existing file: augmented2/train/2/1_29777_left.jpeg
# Skipping existing file: augmented2/train/2/0_29777_right.jpeg
# Skipping existing file: augmented2/train/2/1_29777_right.jpeg
# Skipping existing file: augmented2/train/0/1_29782_left.jpeg
# Skipping existing file: augmented2/train/0/1_29782_right.jpeg
# Skipping existing file: augmented2/train/0/1_29784_left.jpeg
# Skipping existing file: augmented2/train/0/1_29784_right.jpeg
# Skipping existing file: augmented2/train/0/1_29785_left.jpeg
# Skipping existing file: augmented2/train/0/1_29785_right.jpeg
# Skipping existing file: augmented2/train/1/0_29788_left.jpeg
# Skipping existing file: augmented2/train/1/1_29788_left.jpeg
# Skipping existing file: augmented2/train/1/2_29788_left.jpeg
# Skipping existing file: augmented2/train/1/3_29788_left.jpeg
# Skipping existing file: augmented2/train/1/4_29788_left.jpeg
# Skipping existing file: augmented2/train/0/1_29788_right.jpeg
# Skipping existing file: augmented2/train/0/1_29789_left.jpeg
# Skipping existing file: augmented2/train/0/1_29789_right.jpeg
# Skipping existing file: augmented2/train/0/1_29790_left.jpeg
# Skipping existing file: augmented2/train/0/1_29790_right.jpeg
# Skipping existing file: augmented2/train/0/1_29793_left.jpeg
# Skipping existing file: augmented2/train/0/1_29793_right.jpeg
# Skipping existing file: augmented2/train/0/1_29796_left.jpeg
# Skipping existing file: augmented2/train/0/1_29796_right.jpeg
# Skipping existing file: augmented2/train/0/1_29801_left.jpeg
# Skipping existing file: augmented2/train/0/1_29801_right.jpeg
# Skipping existing file: augmented2/train/0/1_29802_left.jpeg
# Skipping existing file: augmented2/train/0/1_29802_right.jpeg
# Skipping existing file: augmented2/train/1/0_29803_left.jpeg
# Skipping existing file: augmented2/train/1/1_29803_left.jpeg
# Skipping existing file: augmented2/train/1/2_29803_left.jpeg
# Skipping existing file: augmented2/train/1/3_29803_left.jpeg
# Skipping existing file: augmented2/train/1/4_29803_left.jpeg
# Skipping existing file: augmented2/train/1/0_29803_right.jpeg
# Skipping existing file: augmented2/train/1/1_29803_right.jpeg
# Skipping existing file: augmented2/train/1/2_29803_right.jpeg
# Skipping existing file: augmented2/train/1/3_29803_right.jpeg
# Skipping existing file: augmented2/train/1/4_29803_right.jpeg
# Skipping existing file: augmented2/train/0/1_29804_left.jpeg
# Skipping existing file: augmented2/train/0/1_29804_right.jpeg
# Skipping existing file: augmented2/train/1/0_29810_left.jpeg
# Skipping existing file: augmented2/train/1/1_29810_left.jpeg
# Skipping existing file: augmented2/train/1/2_29810_left.jpeg
# Skipping existing file: augmented2/train/1/3_29810_left.jpeg
# Skipping existing file: augmented2/train/1/4_29810_left.jpeg
# Skipping existing file: augmented2/train/1/0_29810_right.jpeg
# Skipping existing file: augmented2/train/1/1_29810_right.jpeg
# Skipping existing file: augmented2/train/1/2_29810_right.jpeg
# Skipping existing file: augmented2/train/1/3_29810_right.jpeg
# Skipping existing file: augmented2/train/1/4_29810_right.jpeg
# Skipping existing file: augmented2/train/0/1_29811_left.jpeg
# Skipping existing file: augmented2/train/0/1_29811_right.jpeg
# Skipping existing file: augmented2/train/2/0_29816_left.jpeg
# Skipping existing file: augmented2/train/2/1_29816_left.jpeg
# Skipping existing file: augmented2/train/2/0_29816_right.jpeg
# Skipping existing file: augmented2/train/2/1_29816_right.jpeg
# Skipping existing file: augmented2/train/2/0_29817_left.jpeg
# Skipping existing file: augmented2/train/2/1_29817_left.jpeg
# Processed 24000 images.
# Processed 24500 images.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/farzamani/dl/dataset_utils.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> image_path = os.path.join(image_folder_path, f"{image_name}.jpeg")  # Adjust the extension based on your image format
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> if level == 0:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     augment_and_save(image_path, output_folder_path, level, replicate=1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> elif level == 1:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     for i in range(5):
#
# /home/farzamani/dl/dataset_utils.ipynb Cell 7 line 1
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=107'>108</a> image = Image.open(input_path)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=109'>110</a> # Convert PIL Image to NumPy array
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=110'>111</a> image_np = np.array(image)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=112'>113</a> # Apply the transformations
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/farzamani/dl/dataset_utils.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=113'>114</a> image_np = load_ben_color(image_np)
#
# File ~/mambaforge-pypy3/envs/pytorch/lib/python3.11/site-packages/PIL/Image.py:701, in Image.__array_interface__(self)
#     699         new["data"] = self.tobytes("raw", "L")
#     700     else:
# --> 701         new["data"] = self.tobytes()
#     702 except Exception as e:
#     703     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~/mambaforge-pypy3/envs/pytorch/lib/python3.11/site-packages/PIL/Image.py:758, in Image.tobytes(self, encoder_name, *args)
#     755 if encoder_name == "raw" and args == ():
#     756     args = self.mode
# --> 758 self.load()
#     760 if self.width == 0 or self.height == 0:
#     761     return b""
#
# File ~/mambaforge-pypy3/envs/pytorch/lib/python3.11/site-packages/PIL/ImageFile.py:269, in ImageFile.load(self)
#     266         raise OSError(msg)
#     268 b = b + s
# --> 269 n, err_code = decoder.decode(b)
#     270 if n < 0:
#     271     break
#
# KeyboardInterrupt:

# %% [markdown]
# # Preprocessing Test Images

# %%
import os
import pandas as pd

# Read the CSV file
csv_path = 'dataset/test.csv'
df = pd.read_csv(csv_path)

# Set the path to the folder containing your images
image_folder_path = 'dataset/test'

# Set the path to the output folder for augmented images
output_folder_path = 'augmented2/test'
os.makedirs(output_folder_path, exist_ok=True)

print("Start Preprocessing...")

# Iterate through the CSV file and apply augmentation
n = 0
for index, row in df.iterrows():
    image_name, level = row['id_code'], row['diagnosis']
    image_path = os.path.join(image_folder_path, f"{image_name}.png")  # Adjust the extension based on your image format

    if level == 0:
        for i in range(1):
            augment_and_save(image_path, output_folder_path, level, replicate=i, test=True)
    elif level == 1:
        for i in range(2): #5
            augment_and_save(image_path, output_folder_path, level, replicate=i, test=True)
    elif level == 2:
        for i in range(1): #2
            augment_and_save(image_path, output_folder_path, level, replicate=i, test=True)
    elif level == 3:
        for i in range(3): #9
            augment_and_save(image_path, output_folder_path, level, replicate=i, test=True)
    elif level == 4:
        for i in range(2): #6
            augment_and_save(image_path, output_folder_path, level, replicate=i, test=True)
    
    # augment_and_save(image_path, output_folder_path, level, replicate=1, test=True)

    n += 1
    if n % 200 == 0:
        print(f"Processed {n} images.")
print("Processing complete!")
# Out:
# Start Preprocessing...
# Processed 200 images.
# Processed 400 images.
# Processed 600 images.
# Processed 800 images.
# Processed 1000 images.
# Processed 1200 images.
# Processed 1400 images.
# Processed 1600 images.
# Processed 1800 images.
# Processed 2000 images.
# Processed 2200 images.
# Processed 2400 images.
# Processed 2600 images.
# Processed 2800 images.
# Processed 3000 images.
# Processed 3200 images.
# Processed 3400 images.
# Processed 3600 images.
# Processing complete!

# %%
walk_through_dir("dataset")
walk_through_dir("augmented2")
walk_through_dir("final_dataset")
# Out:
# There are 2 directories and 2 images in 'dataset'.
# There are 0 directories and 3662 images in 'dataset/test'.
# There are 0 directories and 35126 images in 'dataset/train'.
# There are 2 directories and 0 images in 'augmented2'.
# There are 5 directories and 0 images in 'augmented2/test'.
# There are 0 directories and 590 images in 'augmented2/test/4'.
# There are 0 directories and 1805 images in 'augmented2/test/0'.
# There are 0 directories and 999 images in 'augmented2/test/2'.
# There are 0 directories and 740 images in 'augmented2/test/1'.
# There are 0 directories and 579 images in 'augmented2/test/3'.
# There are 5 directories and 0 images in 'augmented2/train'.
# There are 0 directories and 7280 images in 'augmented2/train/4'.
# There are 0 directories and 17304 images in 'augmented2/train/0'.
# There are 0 directories and 7228 images in 'augmented2/train/2'.
# There are 0 directories and 8260 images in 'augmented2/train/1'.
# There are 0 directories and 7566 images in 'augmented2/train/3'.
# There are 2 directories and 0 images in 'final_dataset'.
# There are 2 directories and 0 images in 'final_dataset/test'.
# There are 0 directories and 1805 images in 'final_dataset/test/0'.
# There are 0 directories and 1857 images in 'final_dataset/test/1'.
# There are 2 directories and 0 images in 'final_dataset/train'.
# There are 0 directories and 25810 images in 'final_dataset/train/0'.
# There are 0 directories and 45476 images in 'final_dataset/train/1'.

# %%
# !rsync --checksum --files-from=<(ls augmented/train/0) augmented/train/0/ final_dataset/train/0/
# !rsync --checksum --files-from=<(ls augmented/train/1 | shuf -n 7000) augmented/train/1/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/2 | shuf -n 7000) augmented/train/2/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/3 | shuf -n 7000) augmented/train/3/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/4 | shuf -n 7000) augmented/train/4/ final_dataset/train/1/

# %%
# !mkdir final_dataset
# !mkdir final_dataset/train
# !mkdir final_dataset/train/0
# !mkdir final_dataset/train/1
# !mkdir final_dataset/train/2
# !mkdir final_dataset/test
# !mkdir final_dataset/test/0
# !mkdir final_dataset/test/1
# !mkdir final_dataset/test/2

# %%
# !rsync --checksum --files-from=<(ls augmented/train/0) augmented/train/0/ final_dataset/train/0/
# !rsync --checksum --files-from=<(ls augmented/train/1) augmented/train/1/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/2) augmented/train/2/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/3) augmented/train/3/ final_dataset/train/1/
# !rsync --checksum --files-from=<(ls augmented/train/4) augmented/train/4/ final_dataset/train/1/

# %%
# !rsync --checksum --files-from=<(ls augmented/test/0) augmented/test/0/ final_dataset/test/0/
# !rsync --checksum --files-from=<(ls augmented/test/1) augmented/test/1/ final_dataset/test/1/
# !rsync --checksum --files-from=<(ls augmented/test/2) augmented/test/2/ final_dataset/test/1/
# !rsync --checksum --files-from=<(ls augmented/test/3) augmented/test/3/ final_dataset/test/1/
# !rsync --checksum --files-from=<(ls augmented/test/4) augmented/test/4/ final_dataset/test/1/

# %%
walk_through_dir("augmented")
walk_through_dir("final_dataset")
# Out:
# There are 2 directories and 0 images in 'augmented'.
# There are 5 directories and 0 images in 'augmented/test'.
# There are 0 directories and 295 images in 'augmented/test/4'.
# There are 0 directories and 1805 images in 'augmented/test/0'.
# There are 0 directories and 999 images in 'augmented/test/2'.
# There are 0 directories and 370 images in 'augmented/test/1'.
# There are 0 directories and 193 images in 'augmented/test/3'.
# There are 5 directories and 0 images in 'augmented/train'.
# There are 0 directories and 11328 images in 'augmented/train/4'.
# There are 0 directories and 25810 images in 'augmented/train/0'.
# There are 0 directories and 10584 images in 'augmented/train/2'.
# There are 0 directories and 12215 images in 'augmented/train/1'.
# There are 0 directories and 11349 images in 'augmented/train/3'.
# There are 2 directories and 0 images in 'final_dataset'.
# There are 2 directories and 0 images in 'final_dataset/test'.
# There are 0 directories and 1805 images in 'final_dataset/test/0'.
# There are 0 directories and 1857 images in 'final_dataset/test/1'.
# There are 2 directories and 0 images in 'final_dataset/train'.
# There are 0 directories and 25810 images in 'final_dataset/train/0'.
# There are 0 directories and 45476 images in 'final_dataset/train/1'.

# %% [markdown]
# import os
# import torch
# import torchvision
# from torch.utils.data import DataLoader
#
# def get_mean_std(dataloader):
#     # Initialize variables to accumulate channel-wise means and stds
#     mean_r, mean_g, mean_b = 0.0, 0.0, 0.0
#     std_r, std_g, std_b = 0.0, 0.0, 0.0
#
#     total_samples = 0
#
#     # Iterate through the dataset
#     for data in dataloader:
#         images, _ = data
#         batch_size, channels, height, width = images.size()
#
#         # Calculate mean and std for each channel
#         mean_r += torch.sum(images[:, 0, :, :])
#         mean_g += torch.sum(images[:, 1, :, :])
#         mean_b += torch.sum(images[:, 2, :, :])
#
#         std_r += torch.sum(images[:, 0, :, :] ** 2)
#         std_g += torch.sum(images[:, 1, :, :] ** 2)
#         std_b += torch.sum(images[:, 2, :, :] ** 2)
#
#         total_samples += batch_size * height * width
#
#     # Calculate overall mean and std
#     mean_r /= total_samples
#     mean_g /= total_samples
#     mean_b /= total_samples
#
#     std_r = torch.sqrt(std_r / total_samples - mean_r ** 2)
#     std_g = torch.sqrt(std_g / total_samples - mean_g ** 2)
#     std_b = torch.sqrt(std_b / total_samples - mean_b ** 2)
#
#     # Print the results
#     print(f"Mean - R: {mean_r}, G: {mean_g}, B: {mean_b}")
#     print(f"Std - R: {std_r}, G: {std_g}, B: {std_b}")
#
#
# NUM_WORKERS = os.cpu_count()
#
# train_data = torchvision.datasets.ImageFolder(root="/home/farzamani/dl/final_dataset/train", transform=torchvision.transforms.ToTensor())
# test_data = torchvision.datasets.ImageFolder(root="/home/farzamani/dl/final_dataset/test", transform=torchvision.transforms.ToTensor())
#
# train_dataloader = DataLoader(train_data, num_workers=NUM_WORKERS, batch_size=32, shuffle=True)
# test_dataloader = DataLoader(test_data, num_workers=NUM_WORKERS, batch_size=32, shuffle=True)
#
# get_mean_std(train_dataloader)
# get_mean_std(test_dataloader)
